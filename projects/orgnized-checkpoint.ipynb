# %% [markdown]
# # Home Assistant Events
#
# An event is always fired when something has happened Such as:
#     - an **automation** has been triggered
#     - **state** of entity such as light is changed.
#
# Each event has a **type** and **data**.
#
# The Home Assistant core is using a couple of built-in events to wire all the pieces together.
#
# ## When does Events Fires
#
# ### 1- state_changed
#
# Events are fired when a state has changed. ex.The light when you switch it on the state in home assistant imediatly change.
#
# The event will has the following info the
#     - entity identifier  ex. Light Name or ID
#     - new state ex. Turend On
#     - old state ex Turend Off
#
# If old state is Null it means the state was set for the first time.
#
# If new state is Null, it means the state has been removed or deleted from the eco system.
#
# | Field     | Description                                                           |
# | --------- | --------------------------------------------------------------------- |
# | entity_id | Identifier of the entity that has changed.                            |
# | old_state | The previous state of the entity. Not available if state was created. |
# | new_state | The new state of the entity. Not available if the state was removed.  |
#
#
# ### 2- automation_triggered
#
# This event is fired when an automation is triggered. An automation will trigger an action that can result in more changes being made to the system. The resulting changes can be tracked because all related events will share the same context as this event.
#
# | Field     | Description                                      |
# | --------- | ------------------------------------------------ |
# | name      | Name of the automation that was triggered.       |
# | entity_id | Identifier of the automation that was triggered. |

# %% [markdown]
# ## THE DB
#
# Home assistant store it's events data in a Local Realtional Database of the user choice either SQLite or MariaDB and Postgares.

# %%
pip install --upgrade pyarrow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
from sqlalchemy import create_engine, text

# %%
# Define your database connection URL (modify as per your environment)
db_url = 'mysql+pymysql://homeassistant:homeassistant@192.168.11.198:3306/homeassistant'

# Create a connection to the database
engine = create_engine(db_url)

# %% [markdown]
# ## Database tables
#
# ### Events Table
#
# All events are stored in the database in a table named `events`.
#
# The important fields for the events table are **`event_type_id`, `time_fired_ts`, `data_id`, and `context_id_bin`**.
#
# That information can be used to figure out what happened when, and how it related to other events.
#
#
# | Field                 | Type                                                                 |
# | --------------------- | -------------------------------------------------------------------- |
# | event_id              | Column(Integer, primary_key=True)                                    |
# | origin_idx            | Column(Integer)                                                      |
# | time_fired_ts         | Column(Float, index=True)                                            |
# | context_id_bin        | Column(Blob(16), index=True)                                         |
# | context_user_id_bin   | Column(Blob(16))                                                     |
# | context_parent_id_bin | Column(Blob(16))                                                     |
# | data_id               | Column(Integer, ForeignKey("event_data.data_id"), index=True)        |
# | event_type_id         | Column(Integer, ForeignKey("event_types.event_type_id"))             |

# %%
query = text('''

    SELECT *
    FROM events

''')

# Execute the query and load results into a DataFrame
with engine.connect() as connection:
    events_df = pd.read_sql_query(query, connection)

# Display the result
events_df.head()
# Out:
#    event_id event_type event_data origin  origin_idx time_fired  \
# 0   2002846       None       None   None           0       None
# 1   2002847       None       None   None           0       None
# 2   2002848       None       None   None           0       None
# 3   2002849       None       None   None           0       None
# 4   2002850       None       None   None           0       None
#
#    time_fired_ts context_id context_user_id context_parent_id  data_id  \
# 0   1.738200e+09       None            None              None  54792.0
# 1   1.738200e+09       None            None              None  62226.0
# 2   1.738200e+09       None            None              None  54435.0
# 3   1.738200e+09       None            None              None  62227.0
# 4   1.738200e+09       None            None              None  54417.0
#
#                                       context_id_bin  \
# 0  b'\x01\x94\xb4\xc7\x89\xaa\x94\xa2\xb8Pyb\xf7o...
# ...

# %% [markdown]
# As many `event_data` fields are the same, event_data is stored in the `event_data` table with a many to one relationship on `data_id`:
#
# | Field             | Type                                                                 |
# | ----------------- | -------------------------------------------------------------------- |
# | data_id           | Column(Integer, primary_key=True)                                    |
# | hash              | Column(BigInteger, index=True)                                       |
# | shared_data       | Column(Text().with_variant(mysql.LONGTEXT, "mysql"))                 |

# %%
query = text('''
    SELECT *
    FROM event_data

''')

# Execute the query and load results into a DataFrame
with engine.connect() as connection:
    event_data_df = pd.read_sql_query(query, connection)

# Display the result
event_data_df.head()
# Out:
#    data_id        hash                                       shared_data
# 0        2  2514025343           {"domain":"recorder","service":"purge"}
# 1        3  2001541813  {"domain":"recorder","service":"purge_entities"}
# 2        4   616907209          {"domain":"recorder","service":"enable"}
# 3        5  3478486156         {"domain":"recorder","service":"disable"}
# 4       12  2705000516                          {"component":"recorder"}

# %% [markdown]
# As many `event_type` fields are the same, `event_type` is stored in the `event_types` table with a many to one relationship on `event_type_id`:
#
# | Field             | Type                                                                 |
# | ----------------- | -------------------------------------------------------------------- |
# | event_type_id     | Column(Integer, primary_key=True)                                    |
# | event_type        | Column(String(32), index=True)                                       |

# %%
query = text('''
    SELECT *
    FROM event_types

''')

# Execute the query and load results into a DataFrame
with engine.connect() as connection:
    event_types_df = pd.read_sql_query(query, connection)

# Display the result
event_types_df.head()
# Out:
#    event_type_id              event_type
# 0            151  alarmo_command_success
# 1             14        alexa_smart_home
# 2            131    android.zone_entered
# 3            140     android.zone_exited
# 4            123     automation_reloaded

# %% [markdown]
# ### Finding the event_data for events

# %%
query = text('''

    SELECT * 
    FROM events 
    LEFT JOIN event_data 
    ON (events.data_id=event_data.data_id);

''')

# Execute the query and load results into a DataFrame
with engine.connect() as connection:
    event_types_df = pd.read_sql_query(query, connection)

# Display the result
event_types_df.head()
# Out:
#    event_id event_type event_data origin  origin_idx time_fired  \
# 0   2002846       None       None   None           0       None
# 1   2002847       None       None   None           0       None
# 2   2002848       None       None   None           0       None
# 3   2002849       None       None   None           0       None
# 4   2002850       None       None   None           0       None
#
#    time_fired_ts context_id context_user_id context_parent_id  data_id  \
# 0   1.738200e+09       None            None              None  54792.0
# 1   1.738200e+09       None            None              None  62226.0
# 2   1.738200e+09       None            None              None  54435.0
# 3   1.738200e+09       None            None              None  62227.0
# 4   1.738200e+09       None            None              None  54417.0
#
#                                       context_id_bin  \
# 0  b'\x01\x94\xb4\xc7\x89\xaa\x94\xa2\xb8Pyb\xf7o...
# ...

# %% [markdown]
# The econding of the Data can be Decoed with the following tools:
#     - Constext with HEX
#     - Time Formating with Unixtime in MYSQL or MariaDB.

# %%
# DATE_ADD(FROM_UNIXTIME(states.last_updated_ts), INTERVAL 3 HOUR) AS last_updated_bahrain


query = text('''
SELECT 
    event_id, 
    event_type, 
    DATE_ADD(FROM_UNIXTIME(events.time_fired_ts), INTERVAL 3 HOUR) AS time_fired_ts_bahrain,
    hex(context_parent_id_bin) AS context_parent_id_bin,
    hex(context_id_bin) AS context_id_bin
FROM 
    events;



''')

# Execute the query and load results into a DataFrame
with engine.connect() as connection:
    events_all_df = pd.read_sql_query(query, connection)

# Display the result
display(events_all_df.head())
display(events_all_df.tail())
display(events_all_df.info())
display(events_all_df.shape)
# Out:
#    event_id event_type      time_fired_ts_bahrain context_parent_id_bin  \
# 0   2002846       None 2025-01-30 07:16:03.370352                  None
# 1   2002847       None 2025-01-30 07:16:23.158723                  None
# 2   2002848       None 2025-01-30 07:21:03.364306                  None
# 3   2002849       None 2025-01-30 07:21:22.337298                  None
# 4   2002850       None 2025-01-30 07:26:03.361369                  None
#
#                      context_id_bin
# 0  0194B4C789AA94A2B8507962F76FD717
# 1  0194B4C7D6F61CC71DB5B954848E37A5
# 2  0194B4CC1D848333844F556F22C71C0E
# 3  0194B4CC67A12DBC3506967CCA9495FA
# 4  0194B4D0B161C1A77AD5F4E3B76EBDB9
#        event_id event_type      time_fired_ts_bahrain context_parent_id_bin  \
# 22351   2025203       None 2025-02-09 22:17:43.325827                  None
# 22352   2025204       None 2025-02-09 22:18:15.637740                  None
# 22353   2025205       None 2025-02-09 22:22:03.298061                  None
# ...

# %% [markdown]
# ### Query 1: Fetch and Inspect Events Data

# %%
from IPython.display import display


query = text('''
    SELECT e.event_id, et.event_type_id, et.event_type, e.time_fired_ts, e.context_id_bin, e.context_parent_id_bin, e.context_user_id_bin, e.data_id, e.origin_idx
FROM events e 
JOIN event_types et 
on e.event_type_id = et.event_type_id 

''')

# Execute the query and load results into a DataFrame
with engine.connect() as connection:
    events_join_type_id_df = pd.read_sql_query(query, connection)

# Display the result
display(events_join_type_id_df.head())
display(events_join_type_id_df.tail())
display(events_join_type_id_df.info())
display(events_join_type_id_df.shape)
# Out:
#    event_id  event_type_id              event_type  time_fired_ts  \
# 0   2023860            151  alarmo_command_success   1.739035e+09
# 1   2023912            151  alarmo_command_success   1.739038e+09
# 2   2005162             14        alexa_smart_home   1.738383e+09
# 3   2009651             14        alexa_smart_home   1.738591e+09
# 4   2009652             14        alexa_smart_home   1.738591e+09
#
#                                       context_id_bin context_parent_id_bin  \
# 0  b'\x01\x94\xe6\x8a\xc6\x1f\xd3\xc3\xe8\x91\x06...                  None
# 1  b'\x01\x94\xe6\xc2\xeb!|"R\x13,\x18\xc3\x99a\x1d'                  None
# 2  b'\x01\x94\xbf\xb3\x12\xd4\xe9\x9e\x8b\x91\xfc...                  None
# 3  b'\x01\x94\xcc\x1a\xb1\xd3\xa8N\xa18#n=\x1e9\xf8'                  None
# 4  b'\x01\x94\xcc\x1a\xb1\xed\xfe?N\xa6\xd9\xc1w\...                  None
#
#                                  context_user_id_bin  data_id  origin_idx
# ...

# %%
query = text('''
    SELECT 
    e.event_id, 
    et.event_type_id, 
    et.event_type,                 
    e.time_fired_ts, 
    e.context_id_bin, 
    e.context_parent_id_bin, 
    e.context_user_id_bin, 
    e.data_id, 
    e.origin_idx,
    ed.shared_data,
    ed.hash							
FROM events e
JOIN event_data ed 
ON e.data_id = ed.data_id
JOIN event_types et 
ON e.event_type_id = et.event_type_id

''')

# Execute the query and load results into a DataFrame
with engine.connect() as connection:
    events_join_type_id_df = pd.read_sql_query(query, connection)

# Display the result
display(events_join_type_id_df.head())
display(events_join_type_id_df.tail())
display(events_join_type_id_df.info())
display(events_join_type_id_df.describe())
events_join_type_id_df.shape
# Out:
#    event_id  event_type_id          event_type  time_fired_ts  \
# 0   2008664              1  service_registered   1.738574e+09
# 1   2015094              1  service_registered   1.738764e+09
# 2   2015856              1  service_registered   1.738770e+09
# 3   2017193              1  service_registered   1.738795e+09
# 4   2017905              1  service_registered   1.738797e+09
#
#                                       context_id_bin context_parent_id_bin  \
# 0  b'\x01\x94\xcb\x1a\x13\x1e\x9f"{\x0c6r\xf6\x8d...                  None
# 1  b'\x01\x94\xd6n\x80(\x9f"{\x0c6r\xf6\x8d\xf4\xb0'                  None
# 2  b'\x01\x94\xd6\xc0\x18\x16\x9f"{\x0c6r\xf6\x8d...                  None
# 3  b'\x01\x94\xd8B\x8fR\x9f"{\x0c6r\xf6\x8d\xf4\xb0'                  None
# 4  b'\x01\x94\xd8c\xdd\x1fO\xf9o\xc0VRG\xfc\x02\xda'                  None
#
#   context_user_id_bin  data_id  origin_idx  \
# 0                None        2           0
# 1                None        2           0
# ...

# %%
query = text('''
SELECT event_id, from_unixtime(time_fired_ts), event_types.event_type,
       shared_data, hex(context_id_bin)
 
FROM events 
LEFT JOIN event_data on (events.data_id=event_data.data_id) 
LEFT JOIN event_types ON (events.event_type_id=event_types.event_type_id);

''')


# Execute the query and load results into a DataFrame
with engine.connect() as connection:
    events_join_type_id_df = pd.read_sql_query(query, connection)

# Display the result
events_join_type_id_df.head()
# Out:
#    event_id from_unixtime(time_fired_ts)               event_type  \
# 0   2002846   2025-01-30 04:16:03.370352  entity_registry_updated
# 1   2002847   2025-01-30 04:16:23.158723    google_assistant_sync
# 2   2002848   2025-01-30 04:21:03.364306  entity_registry_updated
# 3   2002849   2025-01-30 04:21:22.337298    google_assistant_sync
# 4   2002850   2025-01-30 04:26:03.361369  entity_registry_updated
#
#                                          shared_data  \
# 0  {"action":"update","entity_id":"media_player.s...
# 1  {"request_id":"16448376342144482534","source":...
# 2  {"action":"update","entity_id":"media_player.s...
# 3  {"request_id":"3027956952592173029","source":"...
# 4  {"action":"update","entity_id":"media_player.s...
#
#                 hex(context_id_bin)
# 0  0194B4C789AA94A2B8507962F76FD717
# 1  0194B4C7D6F61CC71DB5B954848E37A5
# 2  0194B4CC1D848333844F556F22C71C0E
# 3  0194B4CC67A12DBC3506967CCA9495FA
# 4  0194B4D0B161C1A77AD5F4E3B76EBDB9

# %%
# Assuming events_join_type_id_df is your DataFrame
events_join_type_id_df.to_csv('events_final.csv', index=False)

# %% [markdown]
# ### Query 2: Analyze Event Types
# This query counts the number of occurrences for each event type.

# %%
query = text('''
    SELECT 
        et.event_type,
        COUNT(e.event_id) AS event_count
    FROM events e
    LEFT JOIN event_types et ON e.event_type_id = et.event_type_id
    GROUP BY et.event_type
    ORDER BY event_count DESC;
''')

# Execute the query and load results into a DataFrame
with engine.connect() as connection:
    event_types_df = pd.read_sql_query(query, connection)

# Display the results
event_types_df.head(40)
# Out:
#                         event_type  event_count
# 0                     call_service         5519
# 1          entity_registry_updated         4830
# 2            google_assistant_sync         2838
# 3                 alexa_smart_home         2454
# 4               service_registered         2179
# 5             automation_triggered         1814
# 6                 component_loaded          834
# 7          device_registry_updated          447
# 8   repairs_issue_registry_updated          248
# 9                    logbook_entry          222
# 10               ios.became_active          198
# 11          ios.entered_background          171
# 12            homekit_state_change          135
# 13                  panels_updated          112
# 14            android.zone_entered           75
# 15          ios.finished_launching           42
# 16                lovelace_updated           35
# 17                   telegram_sent           32
# 18                ios.zone_entered           23
# ...

# %%
pip install scipy
# Out:
# ...
#    ---------------------------------------- 0.0/43.6 MB ? eta -:--:--
#    -- ------------------------------------- 2.6/43.6 MB 15.1 MB/s eta 0:00:03
#    ----- ---------------------------------- 6.3/43.6 MB 16.8 MB/s eta 0:00:03
#    ------- -------------------------------- 8.7/43.6 MB 14.9 MB/s eta 0:00:03
#    -------- ------------------------------- 9.7/43.6 MB 11.8 MB/s eta 0:00:03
#    --------- ------------------------------ 10.7/43.6 MB 10.5 MB/s eta 0:00:04
#    ----------- ---------------------------- 12.1/43.6 MB 9.6 MB/s eta 0:00:04
#    ------------ --------------------------- 13.1/43.6 MB 8.9 MB/s eta 0:00:04
#    ------------ --------------------------- 14.2/43.6 MB 8.5 MB/s eta 0:00:04
#    ------------- -------------------------- 15.2/43.6 MB 8.0 MB/s eta 0:00:04
#    -------------- ------------------------- 16.3/43.6 MB 7.8 MB/s eta 0:00:04
#    ---------------- ----------------------- 17.6/43.6 MB 7.5 MB/s eta 0:00:04
# ...

# %%
import matplotlib.pyplot as plt
import scipy
import pandas as pd
from sqlalchemy import create_engine, text,
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[51], line 4
#       1 import matplotlib.pyplot as plt
#       3 import pandas as pd
# ----> 4 from sqlalchemy import create_engine, text, scipy
#
# ImportError: cannot import name 'scipy' from 'sqlalchemy' (c:\Users\Bader\anaconda3\Lib\site-packages\sqlalchemy\__init__.py)

# %%
# Plot the all event types
event_types_df.plot(kind='hist', color='green', binfigsize=(10, 6))
plt.title('Event Types')
# plt.xlabel('Event Type')
# plt.ylabel('Frequency')
# plt.xticks(rotation=75)
plt.grid(True)

#('line', 'bar', 'barh', 'kde', 'density', 'area', 'hist', 'box', 'pie', 'scatter', 'hexbin')

# %%
# Filter for the top 10 event types by frequency
top_10_event_types = event_types_df.nlargest(10, 'event_count')

# Plot the top 10 event types
top_10_event_types.plot(kind='bar', x='event_type', y='event_count', color='skyblue', figsize=(10, 6))
plt.title('Top 10 Event Types')
plt.xlabel('Event Type')
plt.ylabel('Frequency')
plt.xticks(rotation=75)
plt.grid(True)


#('line', 'bar', 'barh', 'kde', 'density', 'area', 'hist', 'box', 'pie', 'scatter', 'hexbin')

# %%
query = text('''
    SELECT 
        et.event_type,
        COUNT(e.event_id) AS event_count
    FROM events e
    LEFT JOIN event_types et ON e.event_type_id = et.event_type_id
    GROUP BY et.event_type
    ORDER BY event_count DESC;
''')

# Execute the query and load the data into a DataFrame
with engine.connect() as connection:
    event_types_df = pd.read_sql_query(query, connection)

# --- Data Analysis ---
# Display the top rows to verify the data
print(event_types_df.head())

# --- Visualization ---
# Set up the plot figure with two subplots
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

# --- KDE Plot ---
axes[0].set_title('KDE Plot of Event Counts')
event_types_df['event_count'].plot(kind='kde', ax=axes[0], color='green', linewidth=2)
axes[0].set_xlabel('Event Count')
axes[0].set_ylabel('Density')
axes[0].grid(True)

# --- Box Plot ---
axes[1].set_title('Box Plot of Event Counts')
event_types_df.boxplot(column='event_count', ax=axes[1])
axes[1].set_xlabel('Event Count')
axes[1].set_ylabel('Value')
axes[1].grid(True)

# Display the plots
plt.tight_layout()
plt.show()
# Out:
#                 event_type  event_count
# 0             call_service         5541
# 1  entity_registry_updated         4831
# 2    google_assistant_sync         2839
# 3         alexa_smart_home         2454
# 4       service_registered         2179
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[48], line 25
#      23 # --- KDE Plot ---
#      24 axes[0].set_title('KDE Plot of Event Counts')
# ---> 25 event_types_df['event_count'].plot(kind='kde', ax=axes[0], color='green', linewidth=2)
#      26 axes[0].set_xlabel('Event Count')
#      27 axes[0].set_ylabel('Density')
#
# File c:\Users\Bader\anaconda3\Lib\site-packages\pandas\plotting\_core.py:1030, in PlotAccessor.__call__(self, *args, **kwargs)
#    1027             label_name = label_kw or data.columns
#    1028             data.columns = label_name
# -> 1030 return plot_backend.plot(data, kind=kind, **kwargs)
#
# ...

# %%
v

# %%
query = text('''
   SELECT 
    HOUR(FROM_UNIXTIME(time_fired_ts)) AS event_hour, 
    COUNT(*) AS event_count
FROM events
GROUP BY event_hour
ORDER BY event_hour;

''')

# Execute the query and load results into a DataFrame
with engine.connect() as connection:
    daily_events_df = pd.read_sql_query(query, connection)

# Display the results
daily_events_df.head(40)

# %%
# Plot
plt.figure(figsize=(10, 6))
plt.plot(daily_events_df['event_hour'], daily_events_df['event_count'], marker='o', color='blue')
plt.title('Daily Event Count')
plt.xlabel('Date')
plt.ylabel('Event Count')
plt.grid(True)

# %% [markdown]
# ### Query 3: Analyze Events Over Time
# This query counts the number of events per day.

# %%
query = text('''
    SELECT 
        DATE(FROM_UNIXTIME(e.time_fired_ts)) AS event_date,
        COUNT(e.event_id) AS daily_event_count
    FROM events e
    GROUP BY event_date
    ORDER BY event_date;
''')

# Execute the query and load results into a DataFrame
with engine.connect() as connection:
    daily_events_df = pd.read_sql_query(query, connection)

# Display the results
daily_events_df.head(100)

# %%
# Plot daily event frequency
daily_events_df.plot(x='event_date', y='daily_event_count', kind='line', figsize=(12, 6), color='orange')
plt.title('Daily Event Frequency')
plt.xlabel('Date')
plt.ylabel('Number of Events')
plt.grid(True)
plt.show()

# %% [markdown]
# # Exploring State Changes and Attributes in Home Assistant

# %% [markdown]
# An IoT device or data from a service is represented as one or more entities in Home Assistant. An entity in the core is represented as a state.
#
# Each state has an identifier for the entity in the format of `<domain>.<object_id>`, a state and attributes that further describe the state. An example of this would be `light.kitchen` with the state `on` and attributes describing the color and the brightness.
#
# The `<domain>` part of an entity identifier is equal to the Home Assistant component that is maintaining the state. This domain can be used to figure out what kind of state attributes to expect.

# %% [markdown]
# ## Database
#
# All states are stored in the database in a table named `states`.
#
# The difference between `last_changed_ts` and `last_updated_ts` is that `last_changed_ts` only updates when the `state` value was changed while `last_updated_ts` is updated on any change to the state, even if that included just attributes. Example: if a light turns on, the state changes from `off` to `on`, so both `last_updated_ts` and `last_changed_ts` will update. If a light changes color from red to blue, only the state attributes change. In this case only `last_updated_ts` will change. By distinguishing between these two values, we can easily identify how long a light has been on and how long it has been on the current color/brightness.
#
# The `last_changed_ts` field is not stored in the database when it is the same as the `last_updated_ts` field. See [Fetching the last_changed_ts when it is NULL](#fetching-the-last_changed_ts-when-it-is-null) for queries to populate the value when it is NULL.

# %%
# Define the query
query = '''
SELECT *
FROM states 
LIMIT 10;

'''

# Execute the query and load results into a DataFrame
with engine.connect() as connection:
    states_df = pd.read_sql_query(query, connection)

# Display the results
states_df.head()

# %% [markdown]
# ### Attributes
#
# The `created` field is no longer stored in the `states` table to avoid duplicating data in the database as it was always the same as `last_updated_ts` and the matching `state_change` event's `time_fired_ts`.
#
# As many `attributes` are the same, attributes are stored in the `state_attributes` table with many to one relationship:

# %%
# Define the query
query = '''
SELECT *
FROM state_attributes 
LIMIT 10;

'''

# Execute the query and load results into a DataFrame
with engine.connect() as connection:
    states_attributes_df = pd.read_sql_query(query, connection)

# Display the results
states_attributes_df.head()

# %% [markdown]
# The [Example queries](#example-queries) show how to find `attributes` that were recorded after the change over.
#
# As many `entity_id` fields are the same, `entity_id` is stored in the `states_meta` table with a many to one relationship on `metadata_id`:

# %%
# Define the query
query = '''
SELECT *
FROM states_meta
LIMIT 10;

'''

# Execute the query and load results into a DataFrame
with engine.connect() as connection:
    states_meta_df = pd.read_sql_query(query, connection)

# Display the results
states_meta_df.head()

# %% [markdown]
# ## Example queries
#
# ### Significant states
#
# Users are usually not so interested in state updates that only changed the attributes. Attribute only changes can be triggered by a light changing color or a media player changing song (which happens every ~3 minutes!). Since `last_changed_ts` is `NULL` when it has not changed, it's easy to filter for just the states where the state was changed:

# %%
# Define the query
query = '''
SELECT 
    states_meta.entity_id, 
    state_attributes.shared_attrs, 
    states.last_updated_ts 
FROM 
    states 
LEFT JOIN 
    states_meta ON states.metadata_id = states_meta.metadata_id 
LEFT JOIN 
    state_attributes ON states.attributes_id = state_attributes.attributes_id 
WHERE 
    states.last_changed_ts IS NULL;

'''

# Execute the query and load results into a DataFrame
with engine.connect() as connection:
    states_metaex_df = pd.read_sql_query(query, connection)

# Display the results
states_metaex_df.head()

# %% [markdown]
# ### Linking a new state to an old state
#
# After startup, once a state is changed, the id of the old state is stored as `old_state_id`, making it easy to find the previous state.

# %%
# Define the query
query = '''

SELECT 
    states_meta.entity_id, 
    states.state_id, 
    old_states.state_id, 
    state_attributes.shared_attrs, 
    states.last_updated_ts 
FROM 
    states 
LEFT JOIN 
    states AS old_states ON states.old_state_id = old_states.state_id 
LEFT JOIN 
    states_meta ON (states.metadata_id = states_meta.metadata_id) 
LEFT JOIN 
    state_attributes ON (states.attributes_id = state_attributes.attributes_id);


'''

# Execute the query and load results into a DataFrame
with engine.connect() as connection:
    link_new_to_old_state_df = pd.read_sql_query(query, connection)

# Display the results
link_new_to_old_state_df.head()

# %% [markdown]
# ### Fetching attributes
#
# Attributes are stored in the `state_attributes` table.

# %%
# Define the query
query = '''

SELECT 
    states.state_id, 
    state_attributes.shared_attrs 
FROM 
    states 
LEFT JOIN 
    state_attributes 
ON 
    states.attributes_id = state_attributes.attributes_id

'''

# Execute the query and load results into a DataFrame
with engine.connect() as connection:
    fetching_attributes_df = pd.read_sql_query(query, connection)

# Display the results
fetching_attributes_df.head()

# %% [markdown]
# Attributes can be found in the following order `state_attributes.shared_attrs` or `states.attributes`.
# As new states are recorded `states.attributes` will be phased out.
#
# ### Fetching the last_changed_ts when it is NULL

# %%
# Define the query
query = '''

SELECT 
    states_meta.entity_id, 
    states.state, 
    states.last_updated_ts, 
    IF(
        states.last_changed_ts IS NULL, 
        states.last_updated_ts, 
        states.last_changed_ts
    ) AS last_changed_ts 
FROM 
    states 
LEFT JOIN 
    states_meta 
ON 
    (states.metadata_id = states_meta.metadata_id);

'''

# Execute the query and load results into a DataFrame
with engine.connect() as connection:
    fetching_attributes_null_df = pd.read_sql_query(query, connection)

# Display the results
fetching_attributes_null_df.head()

# %% [markdown]
# ### Viewing state data in a human readable format

# %%
# Define the query
query = '''
SELECT 
    states.state_id, 
    states_meta.entity_id, 
    from_unixtime(states.last_updated_ts) AS last_update,
    from_unixtime(if(states.last_changed_ts 
    IS NULL,states.last_updated_ts,states.last_changed_ts)) AS last_changed, 
    state_attributes.shared_attrs, 
    hex(states.context_id_bin) 
FROM 
    states 
LEFT JOIN 
    states_meta
ON 
    (states.metadata_id=states_meta.metadata_id) 
LEFT JOIN 
    state_attributes 
ON 
    (states.attributes_id=state_attributes.attributes_id) 
WHERE last_changed_ts IS NULL;


'''

# Execute the query and load results into a DataFrame
with engine.connect() as connection:
    states_readable_df = pd.read_sql_query(query, connection)

# Display the results
display(event_states_df.head())
display(event_states_df.tail())
display(event_states_df.info())
display(event_states_df.shape)

# %%
query = text('''
    SELECT * 
    FROM states
''')

# Execute the query and load results into a DataFrame
with engine.connect() as connection:
    state_df = pd.read_sql_query(query, connection)

# Display the results
state_df.head()

# %%
query = text('''
    SELECT * 
    FROM states_meta

''')

# Execute the query and load results into a DataFrame
with engine.connect() as connection:
    states_meta_df = pd.read_sql_query(query, connection)

# Display the results
states_meta_df.head()

# %%
#states_meta_df.to_csv('states_meta.csv', index=False)

# %%
query = text('''
    SELECT * 
    FROM state_attributes

''')

# Execute the query and load results into a DataFrame
with engine.connect() as connection:
    attributes_df = pd.read_sql_query(query, connection)

# Display the results
attributes_df.head()

# %% [markdown]
# # Exploring State Changes and Attributes in Home Assistant

# %% [markdown]
# An IoT device or data from a service is represented as one or more entities in Home Assistant. An entity in the core is represented as a state.
#
# Each state has an identifier for the entity in the format of `<domain>.<object_id>`, a state and attributes that further describe the state. An example of this would be `light.kitchen` with the state `on` and attributes describing the color and the brightness.
#
# The `<domain>` part of an entity identifier is equal to the Home Assistant component that is maintaining the state. This domain can be used to figure out what kind of state attributes to expect.

# %% [markdown]
# ## Database
#
# All states are stored in the database in a table named `states`.
#
# The difference between `last_changed_ts` and `last_updated_ts` is that `last_changed_ts` only updates when the `state` value was changed while `last_updated_ts` is updated on any change to the state, even if that included just attributes. Example: if a light turns on, the state changes from `off` to `on`, so both `last_updated_ts` and `last_changed_ts` will update. If a light changes color from red to blue, only the state attributes change. In this case only `last_updated_ts` will change. By distinguishing between these two values, we can easily identify how long a light has been on and how long it has been on the current color/brightness.
#
# The `last_changed_ts` field is not stored in the database when it is the same as the `last_updated_ts` field. See [Fetching the last_changed_ts when it is NULL](#fetching-the-last_changed_ts-when-it-is-null) for queries to populate the value when it is NULL.

# %%
# Define the query
query = '''
SELECT *
FROM states 
LIMIT 10;

'''

# Execute the query and load results into a DataFrame
with engine.connect() as connection:
    states_df = pd.read_sql_query(query, connection)

# Display the results
states_df.head()

# %% [markdown]
# ### Attributes
#
# The `created` field is no longer stored in the `states` table to avoid duplicating data in the database as it was always the same as `last_updated_ts` and the matching `state_change` event's `time_fired_ts`.
#
# As many `attributes` are the same, attributes are stored in the `state_attributes` table with many to one relationship:

# %%
# Define the query
query = '''
SELECT *
FROM state_attributes 
LIMIT 10;

'''

# Execute the query and load results into a DataFrame
with engine.connect() as connection:
    states_attributes_df = pd.read_sql_query(query, connection)

# Display the results
states_attributes_df.head()

# %% [markdown]
# The [Example queries](#example-queries) below will show how to find `attributes` that were recorded after the change over.
#
# As many `entity_id` fields are the same, `entity_id` is stored in the `states_meta` table with a many to one relationship on `metadata_id`:

# %%
# Define the query
query = '''
SELECT *
FROM states_meta
LIMIT 10;

'''

# Execute the query and load results into a DataFrame
with engine.connect() as connection:
    states_meta_df = pd.read_sql_query(query, connection)

# Display the results
states_meta_df.head()

# %% [markdown]
# ## Example queries
#
# ### Significant states
#
# Users are usually not so interested in state updates that only changed the attributes. Attribute only changes can be triggered by a light changing color or a media player changing song (which happens every ~3 minutes!). Since `last_changed_ts` is `NULL` when it has not changed, it's easy to filter for just the states where the state was changed:

# %%
# Define the query
query = '''
SELECT 
    states_meta.entity_id, 
    state_attributes.shared_attrs, 
    states.last_updated_ts 
FROM 
    states 
LEFT JOIN 
    states_meta ON states.metadata_id = states_meta.metadata_id 
LEFT JOIN 
    state_attributes ON states.attributes_id = state_attributes.attributes_id 
WHERE 
    states.last_changed_ts IS NULL;

'''

# Execute the query and load results into a DataFrame
with engine.connect() as connection:
    states_metaex_df = pd.read_sql_query(query, connection)

# Display the results
states_metaex_df.head()

# %% [markdown]
# ### Linking a new state to an old state
#
# After startup, once a state is changed, the id of the old state is stored as `old_state_id`, making it easy to find the previous state.

# %%
# Define the query
query = '''

SELECT 
    states_meta.entity_id, 
    states.state_id, 
    old_states.state_id, 
    state_attributes.shared_attrs, 
    states.last_updated_ts 
FROM 
    states 
LEFT JOIN 
    states AS old_states ON states.old_state_id = old_states.state_id 
LEFT JOIN 
    states_meta ON (states.metadata_id = states_meta.metadata_id) 
LEFT JOIN 
    state_attributes ON (states.attributes_id = state_attributes.attributes_id);


'''

# Execute the query and load results into a DataFrame
with engine.connect() as connection:
    link_new_to_old_state_df = pd.read_sql_query(query, connection)

# Display the results
link_new_to_old_state_df.head()

# %% [markdown]
# ### Fetching attributes
#
# Attributes are stored in the `state_attributes` table.

# %%
# Define the query
query = '''

SELECT 
    states.state_id, 
    state_attributes.shared_attrs 
FROM 
    states 
LEFT JOIN 
    state_attributes 
ON 
    states.attributes_id = state_attributes.attributes_id

'''

# Execute the query and load results into a DataFrame
with engine.connect() as connection:
    fetching_attributes_df = pd.read_sql_query(query, connection)

# Display the results
fetching_attributes_df.head()

# %% [markdown]
# Attributes can be found in the following order `state_attributes.shared_attrs` or `states.attributes`.
# As new states are recorded `states.attributes` will be phased out.
#
# ### Fetching the last_changed_ts when it is NULL

# %%
# Define the query
query = '''

SELECT 
    states_meta.entity_id, 
    states.state, 
    states.last_updated_ts, 
    IF(
        states.last_changed_ts IS NULL, 
        states.last_updated_ts, 
        states.last_changed_ts
    ) AS last_changed_ts 
FROM 
    states 
LEFT JOIN 
    states_meta 
ON 
    (states.metadata_id = states_meta.metadata_id);

'''

# Execute the query and load results into a DataFrame
with engine.connect() as connection:
    fetching_attributes_null_df = pd.read_sql_query(query, connection)

# Display the results
fetching_attributes_null_df.head()

# %% [markdown]
# ### Viewing state data in a human readable format

# %%
# Define the query
query = '''
SELECT 
    states.state_id, 
    states_meta.entity_id, 
    from_unixtime(states.last_updated_ts) AS last_update,
    from_unixtime(if(states.last_changed_ts 
    IS NULL,states.last_updated_ts,states.last_changed_ts)) AS last_changed, 
    state_attributes.shared_attrs, 
    hex(states.context_id_bin) 
FROM 
    states 
LEFT JOIN 
    states_meta
ON 
    (states.metadata_id=states_meta.metadata_id) 
LEFT JOIN 
    state_attributes 
ON 
    (states.attributes_id=state_attributes.attributes_id) 
WHERE last_changed_ts IS NULL;


'''

# Execute the query and load results into a DataFrame
with engine.connect() as connection:
    states_readable_df = pd.read_sql_query(query, connection)

# Display the results
states_readable_df.tail()

# %% [markdown]
# ### Finding all events By Union With State
# All events except `state_changed` are stored in the `events` table. The `states.last_updated_ts` and `events.timed_fired_ts` are always the same time.
#
# **A union query can be used to find all the events including `state_changed`:**

# %%
from IPython.display import display


query = text('''
    SELECT 
    event_type, 
    time_fired_ts, 
    event_data.shared_data AS data, 
    NULL AS attributes, 
    context_id 
FROM 
    events 
LEFT JOIN 
    event_data ON events.data_id = event_data.data_id

UNION ALL

SELECT 
    'state_changed' AS event_type, 
    last_updated_ts AS time_fired_ts, 
    NULL AS data, 
    state_attributes.shared_attrs AS attributes, 
    context_id 
FROM 
    states 
LEFT JOIN 
    state_attributes ON states.attributes_id = state_attributes.attributes_id;


''')

# Execute the query and load results into a DataFrame
with engine.connect() as connection:
    events_all_df = pd.read_sql_query(query, connection)

# Display the result
display(events_all_df.head())
display(events_all_df.tail())
display(events_all_df.info())
display(events_all_df.shape)

# %%
# Display the result
display(event_states_df.head())
display(event_states_df.tail())
display(event_states_df.info())
display(event_states_df.shape)

# %% [markdown]
# ### Finding all events
# All events except <code>**_state_changed_**</code> are stored in the events table. The <code>**_states.last_updated_ts_**</code> and <code>**_events.timed_fired_ts_**</code> are always the same time.

# %%
query = text('''
SELECT 
    et.event_type, 
    FROM_UNIXTIME(e.time_fired_ts) AS time_fired_ts_bahrain,
    event_data.shared_data AS data, 
    NULL AS attributes, 
    hex(e.context_id_bin) AS context_id,
    hex(e.context_parent_id_bin) AS context_parent_id_bin
FROM 
    events e
LEFT JOIN 
    event_data ON e.data_id = event_data.data_id
LEFT JOIN
    event_types et ON e.event_type_id = et.event_type_id

UNION ALL

SELECT 
    'state_changed' AS event_type, 
    FROM_UNIXTIME(s.last_updated_ts) AS time_fired_ts_bahrain,
    NULL AS data, 
    state_attributes.shared_attrs AS attributes, 
    hex(s.context_id_bin) AS context_id,
    hex(s.context_parent_id_bin) AS context_parent_id_bin
FROM 
    states s
LEFT JOIN 
    state_attributes ON s.attributes_id = state_attributes.attributes_id;



''')

# Execute the query and load results into a DataFrame
with engine.connect() as connection:
    allevents_df = pd.read_sql_query(query, connection)

# Display the result
display(allevents_df.head())
display(allevents_df.tail())
display(allevents_df.info())
display(allevents_df.shape)
